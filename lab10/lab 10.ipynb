# %%
import csv

class studetails:
    def __init__(self):
        self.dict= {}

    def storedet(self,uid,name,phno,mailid,marks1,marks2,marks3,marks4,marks5,total):
        temp ={
            "uid":uid,
            "name":name,
            "phno":phno,
            "mailid":mailid,
            "marks1":marks1,
            "marks2":marks2,
            "marks3":marks3,
            "marks4":marks4,
            "marks5":marks5,
            "total":total
        }

        self.dict[uid]=temp

    def add_student(self):
        uid=int(input("enter uid"))
        name=input("enter the name")
        phno=input("phno")
        mailid=(input("mailid"))
        marks1=int(input("marks1"))
        marks2=int(input("marks2"))
        marks3=int(input("marks3"))
        marks4=int(input("marks4"))
        marks5=int(input("marks5"))
        total=(marks1+marks2+marks3+marks4+marks5)
        return uid,name,phno,mailid,marks1,marks2,marks3,marks4,marks5,total
    
    def printstudentails(self):
        print(self.dict)

    def view_details(self):
        for item in self.dict:
            print(item)


    def search_det(self):
        search_name=("enter the name you want to search")
        for name in self.dict:
            if name == search_name:
                print(name)
            else:
                print("not found")

    #   # Update existing student details based on student ID
    #   if student_id in self.student_details:
     #       student = self.student_details[student_id]
      #      if name is not None:  
       #         student['name'] = name
        #    if age is not None:
         #       student['age'] = age
          #  if grade is not None:
           #     student['grade'] = grade
        #else:
         #   print(f"Student with ID {student_id} not found in the database.")

    
student1=studetails()

det= open("det.csv")
det_head=det.readline()
det_details=det.readlines()

for item in det_details:
    temp = item.strip().split(',')
    student1.storedet(temp[0],temp[1],temp[2],temp[3],temp[4],temp[5],temp[6],temp[7],temp[8],temp[9])
    student1.printstudentails()

print("menu")
choice=input("enter your choice" )
if choice== "1":
    student1.storedet()
elif choice =="2":
    student1.add_student()
elif choice =="3":
    student1.printstudentails()
elif choice =="4":
    student1.view_details()
elif choice=="5":
    student1.search_det()
else:
    print("invalid")
# Out:
# {'23122023': {'uid': '23122023', 'name': 'pinky', 'phno': '9515358738', 'mailid': 'wsref@gmail.com', 'marks1': '78', 'marks2': '89', 'marks3': '85', 'marks4': '78', 'marks5': '60', 'total': '390'}}
# {'23122023': {'uid': '23122023', 'name': 'pinky', 'phno': '9515358738', 'mailid': 'wsref@gmail.com', 'marks1': '78', 'marks2': '89', 'marks3': '85', 'marks4': '78', 'marks5': '60', 'total': '390'}, '23122025': {'uid': '23122025', 'name': 'chinky', 'phno': '8956255137', 'mailid': 'asdfgccc@gmail.com', 'marks1': '80', 'marks2': '90', 'marks3': '95', 'marks4': '88', 'marks5': '65', 'total': '418'}}
# ...
